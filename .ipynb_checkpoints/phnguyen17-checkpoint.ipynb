# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("http://cluster.earlham.edu/~apc0013/Chicago_crime.csv")

# %%
df.head()
# Out:
#         ID Case Number                    Date                  Block  IUCR  \
# 0  2746413    HJ384532  05/20/2003 08:00:00 PM  072XX S FAIRFIELD AVE  0610
# 1  2746414    HJ385055  05/24/2003 09:25:00 PM   015XX W ROOSEVELT RD  0420
# 2  2746415    HJ384304  05/24/2003 01:10:00 PM  062XX S CLAREMONT AVE  031A
# 3  2746416    HJ384255  05/24/2003 02:00:00 PM       031XX N CLARK ST  0860
# 4  2746418    HJ385442  05/25/2003 02:22:00 AM       031XX N BROADWAY  0810
#
#   Primary Type                     Description Location Description  Arrest  \
# 0     BURGLARY                  FORCIBLE ENTRY            RESIDENCE   False
# 1      BATTERY  AGGRAVATED:KNIFE/CUTTING INSTR             SIDEWALK   False
# 2      ROBBERY                  ARMED: HANDGUN               STREET   False
# 3        THEFT                    RETAIL THEFT   SMALL RETAIL STORE    True
# 4        THEFT                       OVER $500               STREET   False
#
#    Domestic              ...                Ward  Community Area  FBI Code  \
# 0     False              ...                18.0            66.0        05
# 1     False              ...                 2.0            28.0       04B
# 2     False              ...                15.0            66.0        03
# 3     False              ...                44.0             6.0        06
# 4     False              ...                44.0             6.0        06
#
#    X Coordinate Y Coordinate  Year              Updated On   Latitude  \
# 0     1159293.0    1856544.0  2003  02/28/2018 03:56:25 PM  41.762076
# 1     1166352.0    1894784.0  2003  02/28/2018 03:56:25 PM  41.866863
# 2     1161795.0    1863307.0  2003  02/28/2018 03:56:25 PM  41.780583
# 3     1170274.0    1920971.0  2003  02/28/2018 03:56:25 PM  41.938637
# 4     1171708.0    1920869.0  2003  02/28/2018 03:56:25 PM  41.938326
#
#    Longitude                       Location
# 0 -87.691736  (41.762075613, -87.691735556)
# 1 -87.664773  (41.866863003, -87.664772948)
# 2 -87.682378   (41.78058266, -87.682377751)
# 3 -87.649609   (41.938636968, -87.64960867)
# 4 -87.644341  (41.938325571, -87.644341433)
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
labels = ["THEFT", "BATTERY","CRIMINAL DAMAGE","ASSAULT", "DECEPTIVE PRACTICE"]
df = df[df["Primary Type"].isin(labels)]

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.shape
# Out:
# (4162390, 22)

# %%
data = df[df["Date"] > pd.to_datetime("12/31/2017")]

# %%
data["hour"] = data["Date"].apply(lambda x: x.hour)
# Out:
# /mnt/lovelace/software/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
fig, ax = plt.subplots(figsize=(16,7))
data.groupby("hour").count()["Arrest"].plot(kind="bar", ax = ax)

# %%
data.groupby("Primary Type").count()["Arrest"].sort_values(ascending = False).head(12).plot(kind="bar")

# %%
data.groupby("Primary Type").count()["Arrest"].sort_values(ascending = False)
# Out:
# Primary Type
# THEFT                 77244
# BATTERY               59832
# CRIMINAL DAMAGE       32896
# ASSAULT               24530
# DECEPTIVE PRACTICE    22127
# Name: Arrest, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(16,7))

data.groupby(["hour", "Primary Type"]).count()["Arrest"].unstack('Primary Type').plot(kind = "bar", stacked = True, ax = ax)

# %%
data.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location', 'hour'],
#       dtype='object')

# %%
data.drop(["ID", "Case Number", "Date", "Block", "IUCR", "Description", "Arrest", "Domestic", \
           "Beat", "Ward", "FBI Code", "X Coordinate", "Y Coordinate", "Year", "Updated On", \
          "Latitude", "Longitude", "Location"],axis = 1)
# Out:
#                Primary Type                            Location Description  \
# 326276              BATTERY                                       RESIDENCE
# 326293              BATTERY                                       APARTMENT
# 326546                THEFT                                      RESTAURANT
# 326746                THEFT                          VEHICLE NON-COMMERCIAL
# 327066                THEFT  AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA
# 327106                THEFT                                      RESTAURANT
# 328474              BATTERY                                       APARTMENT
# 328686   DECEPTIVE PRACTICE                                       APARTMENT
# 328826                THEFT                                       CTA TRAIN
# 328837   DECEPTIVE PRACTICE                                       RESIDENCE
# 328895                THEFT                              VEHICLE-COMMERCIAL
# 328934                THEFT                                      RESTAURANT
# 329433                THEFT                    COMMERCIAL / BUSINESS OFFICE
# 330289                THEFT                          VEHICLE NON-COMMERCIAL
# 330298                THEFT                                        AIRCRAFT
# 331826      CRIMINAL DAMAGE                                     GAS STATION
# 332941      CRIMINAL DAMAGE                                RESIDENCE-GARAGE
# 334544                THEFT                  PARKING LOT/GARAGE(NON.RESID.)
# 334619      CRIMINAL DAMAGE                                          STREET
# 335175   DECEPTIVE PRACTICE                                           OTHER
# 335178                THEFT                              SMALL RETAIL STORE
# 335181                THEFT                                       CTA TRAIN
# 335224                THEFT                              SMALL RETAIL STORE
# 335254                THEFT                                          STREET
# 335276                THEFT                                       APARTMENT
# 335556                THEFT                                       RESIDENCE
# 335891              BATTERY                          VEHICLE NON-COMMERCIAL
# 335930                THEFT                         RESIDENCE PORCH/HALLWAY
# 335931                THEFT                              GROCERY FOOD STORE
# 344078              ASSAULT                                        SIDEWALK
# ...                     ...                                             ...
# 6348932  DECEPTIVE PRACTICE                                     HOTEL/MOTEL
# 6348934               THEFT                                   ATHLETIC CLUB
# 6348940               THEFT                                          STREET
# 6348942               THEFT                                      DRUG STORE
# 6348944               THEFT                              SMALL RETAIL STORE
# 6348946             BATTERY                                        SIDEWALK
# 6348947               THEFT                              GROCERY FOOD STORE
# 6348949               THEFT                  PARKING LOT/GARAGE(NON.RESID.)
# 6348950     CRIMINAL DAMAGE                                     HOTEL/MOTEL
# 6348951     CRIMINAL DAMAGE                                          STREET
# 6348952             ASSAULT                                           OTHER
# 6348955  DECEPTIVE PRACTICE                                       RESIDENCE
# 6348956               THEFT                                          STREET
# 6348957     CRIMINAL DAMAGE                                          STREET
# 6348958               THEFT                                       RESIDENCE
# 6348959               THEFT                   RESIDENTIAL YARD (FRONT/BACK)
# 6348960               THEFT                                   ATHLETIC CLUB
# 6348964     CRIMINAL DAMAGE                                          STREET
# 6348965     CRIMINAL DAMAGE                                   PARK PROPERTY
# 6348966               THEFT                                           OTHER
# 6348967               THEFT                                          STREET
# 6348969  DECEPTIVE PRACTICE                                             NaN
# 6348971     CRIMINAL DAMAGE                                          STREET
# 6348972               THEFT                                           OTHER
# 6348978               THEFT                                   BAR OR TAVERN
# 6348979               THEFT                                   BAR OR TAVERN
# 6348985               THEFT                                           OTHER
# 6349010  DECEPTIVE PRACTICE                                             NaN
# 6349011               THEFT    AIRPORT TERMINAL MEZZANINE - NON-SECURE AREA
# 6349012  DECEPTIVE PRACTICE                                           OTHER
#
#          District  Community Area  hour
# 326276       16.0            11.0    12
# 326293        3.0            42.0     4
# 326546        1.0            32.0    12
# 326746       19.0             5.0    18
# 327066        8.0            56.0     8
# 327106       18.0             8.0    14
# 328474       11.0            29.0     0
# 328686       15.0            25.0    16
# 328826        1.0            32.0    19
# 328837       19.0             5.0    10
# 328895       10.0            30.0    11
# 328934       18.0             8.0     0
# 329433        1.0            32.0     9
# 330289       22.0            72.0    16
# 330298       16.0            76.0    13
# 331826       24.0             2.0    22
# 332941       16.0            11.0    16
# 334544        1.0            32.0    23
# 334619       25.0            20.0    23
# 335175       14.0            22.0    12
# 335178        9.0            61.0    17
# 335181        1.0            32.0     8
# 335224       19.0             7.0    13
# 335254       12.0            28.0    18
# 335276        1.0            35.0    23
# 335556       18.0             8.0    12
# 335891        7.0            67.0    23
# 335930       12.0            24.0    13
# 335931       20.0             4.0    19
# 344078       15.0            25.0     0
# ...           ...             ...   ...
# 6348932      18.0             8.0     1
# 6348934       2.0            41.0    11
# 6348940      19.0             6.0     9
# 6348942      17.0            16.0    17
# 6348944      18.0             8.0    18
# 6348946       4.0            43.0    15
# 6348947      22.0            75.0    16
# 6348949      14.0            21.0    17
# 6348950      20.0             2.0    20
# 6348951       1.0            33.0    15
# 6348952       1.0            28.0    22
# 6348955      14.0            24.0    16
# 6348956       9.0            61.0     2
# 6348957      12.0            28.0    17
# 6348958       3.0            43.0    13
# 6348959      14.0            22.0    12
# 6348960      25.0            25.0    18
# 6348964      22.0            73.0    20
# 6348965       5.0            49.0    17
# 6348966      12.0            28.0    23
# 6348967      16.0            17.0    21
# 6348969      20.0             4.0    12
# 6348971       9.0            61.0    14
# 6348972       6.0            44.0    14
# 6348978      19.0             7.0     1
# 6348979      14.0            24.0     0
# 6348985      18.0             8.0    10
# 6349010       2.0            36.0    18
# 6349011      16.0            76.0     0
# 6349012       1.0            32.0    15
#
# [216629 rows x 5 columns]

# %%
y = data["Primary Type"]
y.shape
# Out:
# (216629,)

# %%
X =data.drop(["ID", "Case Number", "Date", "Block", "IUCR", "Description", "Arrest", "Domestic", \
           "Beat", "Ward", "FBI Code", "X Coordinate", "Y Coordinate", "Year", "Updated On", \
          "Latitude", "Longitude", "Location", "Primary Type"],axis = 1)
X.shape
# Out:
# (216629, 4)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_test.shape
# Out:
# (43326, 4)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation 
from keras import optimizers

output_dim = len(labels)
model = Sequential()
model.add(Dense(8,kernel_initializer='uniform',input_shape = (4,)))
model.add(Dense(32))
model.add(Activation('softmax'))
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error', optimizer=sgd)
model.fit(X, y,batch_size = 100, epochs = 15, validation_data=(X_test, y_test))
# Out:
# /mnt/lovelace/software/anaconda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-71163d8fbe8d> in <module>()
#       6 model.add(Dense(32))
#       7 model.add(Activation('softmax'))
# ----> 8 sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#       9 model.compile(loss='mean_squared_error', optimizer=sgd)
#      10 model.fit(X, y,batch_size = 100, epochs = 15, validation_data=(X_test, y_test))
#
# NameError: name 'optimizers' is not defined
